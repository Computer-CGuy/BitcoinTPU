# %% [markdown]
# <a href="https://colab.research.google.com/github/Computer-CGuy/BitcoinTPU/blob/main/Incrementation_%7C_Satcoin_%7C%201K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install pycryptosat
# Out:
# ...
#      |████████████████████████████████| 286kB 7.6MB/s
# ...
#   Created wheel for pycryptosat: filename=pycryptosat-0.6.1-cp37-cp37m-linux_x86_64.whl size=2028039 sha256=03a221a1b05a0d52f76979f5561fea47da4b06050e67057523d9fb3403ac51d9
#   Stored in directory: /root/.cache/pip/wheels/99/d9/0f/d8cad805bb1dc767d3873419065f840cb19a51db9f51bef0fc
# Successfully built pycryptosat
# ...

# %%
import time
from pycryptosat import Solver

# %%
# !ls -lh
# Out:
# total 17M
# -rw-r--r-- 1 root root  17M Jul  5 13:32 1K-Nonce-SAT.cnf
# drwxr-xr-x 1 root root 4.0K Jun 15 13:37 sample_data

# %%
solver = Solver()

with open("./1K-Nonce-SAT.cnf", "r") as x:
    for i,line in enumerate(x):
        line = line.strip()
        # if(line[0]=="p" or line[0]=="c"):
        if "p" in line or "c" in line:
            continue

        out = [int(x) for x in line.split()[:-1]]
        # solver.add_clause(out)
#         print(out)
        if(i==655243): # line no. 655243
            main_clause=out
        else:
            solver.add_clause(out)

# %%
# Preprocessing (as per the convention)
for i in range(len(main_clause)-1):
    main_clause[i] = -main_clause[i]

# %%
### 1st Attemo
# SAT
# Genesis Block
# %%timeit
# SATIABLE = [-2887,2888,-2889,-2890,-2891,2892,2893,2894,2895,2896,2897,2898,2899,2900,2901,2902,-2903,-2904,-2905,-2906,-2907,-2908,-2909,-2910,-2911,-2912,-2913,-2914,-2915,-2916,-2917,-2918,135795]
start = time.time()
res, isSAT = solver.solve(main_clause)
# res, isSAT = solver.solve()
done = time.time()
elapsed = done - start
print(elapsed)
print(res,isSAT)
# Out:
# 462.047167301178
# ...

# %%
main_clause[0] = -main_clause[0]

# %%
### 2nd Attempt 
# UNSAT
# [0] = -[0]
# %%timeit
# SATIABLE = [-2887,2888,-2889,-2890,-2891,2892,2893,2894,2895,2896,2897,2898,2899,2900,2901,2902,-2903,-2904,-2905,-2906,-2907,-2908,-2909,-2910,-2911,-2912,-2913,-2914,-2915,-2916,-2917,-2918,135795]
start = time.time()
res, isSAT = solver.solve(main_clause)
# res, isSAT = solver.solve()
done = time.time()
elapsed = done - start
print(elapsed)
print(res,isSAT)
# Out:
# 0.006530046463012695
# False None

# %%
### 3rd Attempt 
# UNSAT
# [0] = +[0]
# Genesis Block (Backend Cached)
# SATIABLE = [-2887,2888,-2889,-2890,-2891,2892,2893,2894,2895,2896,2897,2898,2899,2900,2901,2902,-2903,-2904,-2905,-2906,-2907,-2908,-2909,-2910,-2911,-2912,-2913,-2914,-2915,-2916,-2917,-2918,135795]
start = time.time()
res, isSAT = solver.solve(main_clause)
done = time.time()
elapsed = done - start
print(elapsed)
print(res,isSAT)
# Out:
# 0.04416179656982422
# ...

# %%
from pycryptosat import Solver
s = Solver()
s.add_clause([1])
s.add_clause([3])
# s.add_clause([-1, 2, 3])
sat, solution = s.solve([-1, 2, 3])
print(sat,solution)
# Out:
# False None

# %%
print(solution)
# Out:
# (None, True, False, True)

# %%
sat, solution = s.solve([-3])
print(sat,solution)
# Out:
# False None
